# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("./Downloads/PA1_train.csv", parse_dates=True,index_col=0)
data = data.drop(['date','id'],axis=1)


def plot_corr(data,size=20):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = data.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    cax = ax.matshow(correlations, vmin=-1, vmax=1)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);

    
plot_corr(data.corr())

# %%
# from the correlation graph we can see that the price is...

# %%
data
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# dummy
# 1             4       2.50         2720     10006     2.0           0     0
# 1             2       2.50         2600      5000     1.0           0     0
# 1             5       1.75         1650      3000     1.5           0     0
# 1             4       1.75         1720      9600     1.0           0     0
# 1             6       2.25         3830     11180     1.0           0     2
# 1             4       2.50         2210    213008     1.0           0     0
# 1             3       2.50         2600     23361     1.5           1     4
# 1             4       1.50         1220      4900     1.0           0     0
# 1             3       2.75         3040     24192     2.0           0     0
# 1             2       1.00         1010      5408     1.0           0     0
# 1             4       2.50         2660      4082     2.0           0     0
# ...

# %%
def describe_new(data):
    data1 = data.describe()
    data1.loc["range"] = data1.loc['max'] - data1.loc['min']
    return data1


#describe_new(data)

np.round(describe_new(data), 2).T[['mean', 'std', 'range']]
# Out:
#                    mean       std       range
# bedrooms           3.38      0.94       32.00
# bathrooms          2.12      0.77        7.25
# sqft_living     2080.22    911.33     9520.00
# sqft_lot       15089.20  41203.89  1650787.00
# floors             1.50      0.54        2.50
# waterfront         0.01      0.08        1.00
# view               0.23      0.76        4.00
# condition          3.41      0.65        4.00
# grade              7.67      1.18        9.00
# sqft_above      1793.10    830.87     8490.00
# sqft_basement    287.12    435.01     2720.00
# yr_built        1971.12     29.48      115.00
# yr_renovated      81.23    394.38     2015.00
# zipcode        98078.29     53.52      198.00
# lat               47.56      0.14        0.62
# long            -122.21      0.14        1.19
# sqft_living15   1994.33    691.90     5650.00
# sqft_lot15     12746.32  28241.24   870540.00
# price              5.39      3.57       68.08

# %%
#normalize features
data = data.drop(['price'],axis=1)
data
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# dummy
# 1             4       2.50         2720     10006     2.0           0     0
# 1             2       2.50         2600      5000     1.0           0     0
# 1             5       1.75         1650      3000     1.5           0     0
# 1             4       1.75         1720      9600     1.0           0     0
# 1             6       2.25         3830     11180     1.0           0     2
# 1             4       2.50         2210    213008     1.0           0     0
# 1             3       2.50         2600     23361     1.5           1     4
# 1             4       1.50         1220      4900     1.0           0     0
# 1             3       2.75         3040     24192     2.0           0     0
# 1             2       1.00         1010      5408     1.0           0     0
# 1             4       2.50         2660      4082     2.0           0     0
# ...

# %%
data=((data-data.min())/(data.max()-data.min()))*1

# %%
data
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# dummy
# 1       0.09375   0.275862     0.246849  0.005715     0.4         0.0  0.00
# 1       0.03125   0.275862     0.234244  0.002682     0.0         0.0  0.00
# 1       0.12500   0.172414     0.134454  0.001471     0.2         0.0  0.00
# 1       0.09375   0.172414     0.141807  0.005469     0.0         0.0  0.00
# 1       0.15625   0.241379     0.363445  0.006426     0.0         0.0  0.50
# 1       0.09375   0.275862     0.193277  0.128688     0.0         0.0  0.00
# 1       0.06250   0.275862     0.234244  0.013805     0.2         1.0  1.00
# 1       0.09375   0.137931     0.089286  0.002622     0.0         0.0  0.00
# 1       0.06250   0.310345     0.280462  0.014308     0.4         0.0  0.00
# 1       0.03125   0.068966     0.067227  0.002930     0.0         0.0  0.00
# 1       0.09375   0.275862     0.240546  0.002126     0.4         0.0  0.00
# ...

# %%
import numpy as np
#get x and y from data matrix
data=np.array(data)
X=np.array(data[:,0:-2]).astype('float32')
y=np.array(data[:,-1]).astype('float32')
y=y.reshape(-1,1)
m=y.shape[0]
#initialize w to zero, theta
theta=np.zeros(X.shape[1]).reshape(-1,1)
#
len(theta)
# Out:
# 16

# %% [markdown]
# def cost_function(X, y, theta, alpha):
#     """
#     cost_function(X, y, theta) computes the cost of using theta as the
#     parameter for linear regression to fit the data points in X and y
#     """
#     ## number of training examples
#     m = len(y)
#
#     ## Calculate the cost with the given parameters
#     J = (np.sum((X.dot(theta)-y)**2))+(alpha*(np.sum(theta)**2))
#
#     return J
#
# def gradient_descent(X, y, theta, alpha, iterations):
#     """
#     gradient_descent Performs gradient descent to learn theta
#     theta = GRADIENTDESENT(X, y, theta, alpha, num_iters) updates theta by
#     taking num_iters gradient steps with learning rate alpha
#     """
#     cost_history = [0] * iterations
#
#     for iteration in range(iterations):
#         hypothesis = X.dot(theta)
#         loss = hypothesis-y
#         gradient = X.T.dot(loss)/m
#         theta = theta - alpha*gradient
#         print(gradient)
#         cost = cost_function(X, y, theta, alpha)
#         cost_history[iteration] = cost
#
#     return theta, cost_history

# %%
cost_function(X,y,theta,1)
# Out:
# 12.450746848445435

# %%
#For learning rate 10^0
w,e_iters=gradient_descent(X,y,theta,1,300)
# Out:
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920478]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[ 7.76313158e-04]
#  [ 2.28437631e-03]
#  [ 1.50538577e-03]
#  [-5.25909785e-04]
#  [ 2.66340669e-03]
#  [ 2.15950325e-05]
#  [ 2.75292641e-04]
#  [ 6.23607945e-03]
#  [ 4.04800536e-03]
#  [ 1.32885277e-03]
#  [ 1.12107076e-03]
#  [ 6.35731923e-03]
#  [ 3.04635955e-04]
#  [ 5.32111568e-03]
#  [ 7.68816675e-03]
#  [ 1.70121468e-03]]
# [[-0.00062299]
#  [-0.00203767]
#  [-0.00197139]
#  [-0.00068684]
#  [-0.00142201]
#  [-0.00011561]
#  [-0.00087036]
#  [-0.00497906]
#  [-0.00376542]
#  [-0.00191732]
#  [-0.00091529]
#  [-0.00546248]
#  [-0.00039818]
#  [-0.00219917]
#  [-0.00481276]
#  [-0.00297423]]
# [[ 4.59974164e-04]
#  [ 1.32484910e-03]
#  [ 7.41957230e-04]
#  [-5.57641794e-04]
#  [ 1.74143966e-03]
# ...

# %%
plt.plot(e_iters)
plt.show()

# %%
cost_function(X,y,theta,0.1)
#For learning rate 10^1
w,e_iters=gradient_descent(X,y,theta,0.1,300)
# Out:
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920478]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00087195]
#  [-0.00283098]
#  [-0.00261939]
#  [-0.00072133]
#  [-0.00215807]
#  [-0.00014342]
#  [-0.00109671]
#  [-0.00688355]
#  [-0.0051679 ]
#  [-0.00253243]
#  [-0.00126334]
#  [-0.00764857]
#  [-0.00050814]
#  [-0.00320838]
#  [-0.00682748]
#  [-0.00387068]]
# [[-0.00072112]
#  [-0.00236266]
#  [-0.00224168]
#  [-0.0007034 ]
#  [-0.00171678]
#  [-0.00012829]
#  [-0.00097097]
#  [-0.00568374]
#  [-0.00432444]
#  [-0.00217876]
#  [-0.00104526]
#  [-0.00636618]
#  [-0.00043389]
#  [-0.00243063]
#  [-0.00550093]
#  [-0.00336025]]
# [[-0.00059688]
#  [-0.00197671]
#  [-0.00193032]
#  [-0.00068858]
#  [-0.00135322]
#  [-0.0001158 ]
#  [-0.0008672 ]
#  [-0.00469623]
#  [-0.0036296 ]
#  [-0.00188714]
# ...

# %%
plt.plot(e_iters)
plt.show()

# %%
cost_function(X,y,theta,0.01)
#For learning rate 10^2
w,e_iters=gradient_descent(X,y,theta,0.01,300)
# Out:
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920478]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00103678]
#  [-0.00334251]
#  [-0.00303187]
#  [-0.00074087]
#  [-0.00264022]
#  [-0.00015992]
#  [-0.00123391]
#  [-0.00819551]
#  [-0.00608949]
#  [-0.00291856]
#  [-0.00150178]
#  [-0.00904916]
#  [-0.00058941]
#  [-0.00406133]
#  [-0.00827905]
#  [-0.00442787]]
# [[-0.00101879]
#  [-0.00328668]
#  [-0.00298684]
#  [-0.00073874]
#  [-0.00258759]
#  [-0.00015812]
#  [-0.00121894]
#  [-0.00805232]
#  [-0.00598889]
#  [-0.00287641]
#  [-0.00147575]
#  [-0.00889627]
#  [-0.00058054]
#  [-0.00396826]
#  [-0.00812062]
#  [-0.00436705]]
# [[-0.00100112]
#  [-0.00323182]
#  [-0.00294261]
#  [-0.00073664]
#  [-0.00253589]
#  [-0.00015635]
#  [-0.00120422]
#  [-0.00791166]
#  [-0.00589007]
#  [-0.002835  ]
# ...

# %%
plt.plot(e_iters)
plt.show()

# %%
cost_function(X,y,theta,0.001)
#For learning rate 10^3
w,e_iters=gradient_descent(X,y,theta,0.001,300)
# Out:
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920478]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00105326]
#  [-0.00339367]
#  [-0.00307312]
#  [-0.00074282]
#  [-0.00268844]
#  [-0.00016157]
#  [-0.00124763]
#  [-0.00832671]
#  [-0.00618165]
#  [-0.00295717]
#  [-0.00152562]
#  [-0.00918921]
#  [-0.00059754]
#  [-0.00414663]
#  [-0.0084242 ]
#  [-0.00448359]]
# [[-0.00105144]
#  [-0.00338799]
#  [-0.00306854]
#  [-0.00074261]
#  [-0.00268309]
#  [-0.00016139]
#  [-0.00124611]
#  [-0.00831216]
#  [-0.00617143]
#  [-0.00295289]
#  [-0.00152298]
#  [-0.00917368]
#  [-0.00059664]
#  [-0.00413717]
#  [-0.0084081 ]
#  [-0.00447741]]
# [[-0.00104961]
#  [-0.00338233]
#  [-0.00306397]
#  [-0.00074239]
#  [-0.00267775]
#  [-0.00016121]
#  [-0.00124459]
#  [-0.00829763]
#  [-0.00616122]
#  [-0.00294861]
# ...

# %%
plt.plot(e_iters)
plt.show()

# %%
cost_function(X,y,theta,0.0001)
#For learning rate 10^4
w,e_iters=gradient_descent(X,y,theta,0.0001,300)
# Out:
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920478]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00105491]
#  [-0.00339878]
#  [-0.00307724]
#  [-0.00074302]
#  [-0.00269326]
#  [-0.00016174]
#  [-0.00124901]
#  [-0.00833983]
#  [-0.00619086]
#  [-0.00296103]
#  [-0.00152801]
#  [-0.00920322]
#  [-0.00059835]
#  [-0.00415516]
#  [-0.00843872]
#  [-0.00448917]]
# [[-0.00105473]
#  [-0.00339821]
#  [-0.00307678]
#  [-0.000743  ]
#  [-0.00269272]
#  [-0.00016172]
#  [-0.00124885]
#  [-0.00833837]
#  [-0.00618984]
#  [-0.0029606 ]
#  [-0.00152774]
#  [-0.00920166]
#  [-0.00059826]
#  [-0.00415421]
#  [-0.00843711]
#  [-0.00448855]]
# [[-0.00105455]
#  [-0.00339765]
#  [-0.00307632]
#  [-0.00074298]
#  [-0.00269219]
#  [-0.0001617 ]
#  [-0.0012487 ]
#  [-0.00833691]
#  [-0.00618882]
#  [-0.00296017]
# ...

# %%
plt.plot(e_iters)
plt.show()

# %%
cost_function(X,y,theta,0.00001)
#For learning rate 10^5
w,e_iters=gradient_descent(X,y,theta,0.00001,300)
# Out:
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920478]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00105508]
#  [-0.00339929]
#  [-0.00307765]
#  [-0.00074304]
#  [-0.00269374]
#  [-0.00016175]
#  [-0.00124914]
#  [-0.00834114]
#  [-0.00619178]
#  [-0.00296142]
#  [-0.00152825]
#  [-0.00920462]
#  [-0.00059844]
#  [-0.00415601]
#  [-0.00844017]
#  [-0.00448972]]
# [[-0.00105506]
#  [-0.00339924]
#  [-0.00307761]
#  [-0.00074304]
#  [-0.00269369]
#  [-0.00016175]
#  [-0.00124913]
#  [-0.00834099]
#  [-0.00619168]
#  [-0.00296137]
#  [-0.00152822]
#  [-0.00920446]
#  [-0.00059843]
#  [-0.00415591]
#  [-0.00844001]
#  [-0.00448966]]
# [[-0.00105504]
#  [-0.00339918]
#  [-0.00307756]
#  [-0.00074303]
#  [-0.00269363]
#  [-0.00016175]
#  [-0.00124911]
#  [-0.00834085]
#  [-0.00619158]
#  [-0.00296133]
# ...

# %%
plt.plot(e_iters)
plt.show()

# %%
cost_function(X,y,theta,0.000001)
#For learning rate 10^6
w,e_iters=gradient_descent(X,y,theta,0.000001,300)
# Out:
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920478]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00105509]
#  [-0.00339934]
#  [-0.00307769]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834127]
#  [-0.00619188]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920476]
#  [-0.00059844]
#  [-0.00415609]
#  [-0.00844031]
#  [-0.00448978]]
# [[-0.00105509]
#  [-0.00339934]
#  [-0.00307769]
#  [-0.00074304]
#  [-0.00269378]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834126]
#  [-0.00619187]
#  [-0.00296145]
#  [-0.00152827]
#  [-0.00920475]
#  [-0.00059844]
#  [-0.00415608]
#  [-0.0084403 ]
#  [-0.00448977]]
# [[-0.00105509]
#  [-0.00339933]
#  [-0.00307769]
#  [-0.00074304]
#  [-0.00269378]
#  [-0.00016176]
#  [-0.00124915]
#  [-0.00834124]
#  [-0.00619186]
#  [-0.00296145]
# ...

# %%
plt.plot(e_iters)
plt.show()

# %%
cost_function(X,y,theta,0.0000001)
#For learning rate 10^7
w,e_iters=gradient_descent(X,y,theta,0.0000001,300)
# Out:
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920478]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619189]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920477]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619188]
#  [-0.00296146]
#  [-0.00152827]
#  [-0.00920477]
#  [-0.00059844]
#  [-0.0041561 ]
#  [-0.00844033]
#  [-0.00448978]]
# [[-0.00105509]
#  [-0.00339935]
#  [-0.0030777 ]
#  [-0.00074304]
#  [-0.00269379]
#  [-0.00016176]
#  [-0.00124916]
#  [-0.00834128]
#  [-0.00619188]
#  [-0.00296146]
# ...

# %%
plt.plot(e_iters)
plt.show()
