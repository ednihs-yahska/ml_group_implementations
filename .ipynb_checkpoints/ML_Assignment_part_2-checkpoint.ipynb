# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
weight1 = pd.read_csv('weight_0.0001.csv')
weight2 = pd.read_csv('weight_1e-05.csv')
weight3 = pd.read_csv('weight_1e-06.csv')
weight4 = pd.read_csv('weight_1e-07.csv')

# %%
weight1
# Out:
#       weight  feature
# 0  -6.314734        1
# 1  -0.016919        2
# 2   7.585033        3
# 3  -0.756257        4
# 4   4.918300        5
# 5   2.960866        6
# 6   7.681923        7
# 7   8.606310        8
# 8   2.481608        9
# 9   4.239114       10
# 10  0.166684       11
# 11 -3.195887       12

# %%
diff_wt ={
    0.0001:weight1.weight,
    0.00001:weight2.weight,
    0.000001:weight3.weight,
    0.0000001:weight4.weight
}

# %%
features = pd.read_csv('features_used.csv')
x_names = np.array(features['names'])

# %%
x_names
# Out:
# array(['bedrooms', 'bathrooms', 'sqft_living', 'floors', 'waterfront',
#        'view', 'grade', 'sqft_above', 'sqft_basement', 'lat',
#        'sqft_living15', 'dummy'], dtype=object)

# %%
main_df_val = pd.read_csv('PA1_dev.csv.xls')

# %%
df_val = main_df_val[x_names]
df_val.head()
# Out:
#    bedrooms  bathrooms  sqft_living  floors  waterfront  view  grade  \
# 0         3       2.25         2570     2.0           0     0      7
# 1         3       2.00         1680     1.0           0     0      8
# 2         3       2.50         3560     1.0           0     0      8
# 3         2       1.00         1160     1.0           0     0      7
# 4         3       2.00         1890     2.0           0     0      7
#
#    sqft_above  sqft_basement      lat  sqft_living15  dummy
# 0        2170            400  47.7210           1690      1
# 1        1680              0  47.6168           1800      1
# 2        1860           1700  47.6007           2210      1
# 3         860            300  47.6900           1330      1
# 4        1890              0  47.7277           1890      1

# %%
df_val = df_val.drop(['dummy'],1)

# %%
for feature in df_val.columns:
    mn = df_val[feature].min()
    rnge = df_val[feature].max() - df_val[feature].min()
    df_val[feature] = df_val[feature].apply(lambda x : (x-mn)/rnge)

# %%
df_val['dummy']=main_df_val['dummy']

# %%
df_val.head()
# Out:
#    bedrooms  bathrooms  sqft_living  floors  waterfront  view  grade  \
# 0     0.250   0.206897     0.165779     0.4         0.0   0.0    0.4
# 1     0.250   0.172414     0.098099     0.0         0.0   0.0    0.5
# 2     0.250   0.241379     0.241065     0.0         0.0   0.0    0.5
# 3     0.125   0.034483     0.058555     0.0         0.0   0.0    0.4
# 4     0.250   0.172414     0.114068     0.4         0.0   0.0    0.4
#
#    sqft_above  sqft_basement       lat  sqft_living15  dummy
# 0    0.197339       0.082988  0.908027       0.184116      1
# 1    0.143016       0.000000  0.738707       0.203971      1
# 2    0.162971       0.352697  0.712545       0.277978      1
# 3    0.052106       0.062241  0.857654       0.119134      1
# 4    0.166297       0.000000  0.918915       0.220217      1

# %%
def calculate_sse(weight):
    print(df_val.shape,weight.shape)
    p = df_val.dot(np.array(weight)) 
    y = main_df_val['price']
    diff = p - y
    sse = (np.transpose(diff)).dot(diff)
    return sse

# %%
learning_rate = [0.0001,0.00001,0.000001,0.0000001]
for lr in learning_rate:
    sse = calculate_sse(diff_wt[lr])
    print("lr = ",lr," sse = ",sse)
# Out:
# (5597, 12) (12,)
# lr =  0.0001  sse =  42092.233530221536
# (5597, 12) (12,)
# lr =  1e-05  sse =  42392.654374075384
# (5597, 12) (12,)
# lr =  1e-06  sse =  31865.8394104541
# (5597, 12) (12,)
# lr =  1e-07  sse =  26098.742670731357

# %%
############### thus choosing learn rate = 10**(-7)

# %%
main_df_train = pd.read_csv('PA1_train.csv.xls')
df_train = main_df_train.drop(['id','dummy'],1)

# %%
df_train.columns
# Out:
# Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
df_train['date'] = pd.to_datetime(main_df_train['date'])
df_train['month'] = df_train['date'].apply(lambda x:x.month)
df_train['year'] =  df_train['date'].apply(lambda x:x.year)
df_train['day'] = df_train['date'].apply(lambda x:x.day)

# %%
df_train.columns.shape
# Out:
# (23,)

# %%
df_train = df_train.drop(['date'],1)
df_train.shape
# Out:
# (10000, 22)

# %%
df_train.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price', 'month', 'year', 'day'],
#       dtype='object')

# %%
y_train = df_train['price']
df_train = df_train.drop(['price'],1)

# %%
for feature in df_train.columns:
    mn = df_train[feature].min()
    rnge = df_train[feature].max() - df_train[feature].min()
    df_train[feature] = df_train[feature].apply(lambda x : (x-mn)/rnge)

# %%
df_train.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0   0.09375   0.275862     0.246849  0.005715     0.4         0.0   0.0
# 1   0.03125   0.275862     0.234244  0.002682     0.0         0.0   0.0
# 2   0.12500   0.172414     0.134454  0.001471     0.2         0.0   0.0
# 3   0.09375   0.172414     0.141807  0.005469     0.0         0.0   0.0
# 4   0.15625   0.241379     0.363445  0.006426     0.0         0.0   0.5
#
#    condition     grade  sqft_above    ...     yr_built  yr_renovated  \
# 0       0.50  0.555556    0.276796    ...     0.773913           0.0
# 1       1.00  0.444444    0.109541    ...     0.226087           0.0
# 2       0.50  0.444444    0.150766    ...     0.017391           0.0
# 3       0.75  0.444444    0.159011    ...     0.600000           0.0
# 4       1.00  0.555556    0.243816    ...     0.539130           0.0
#
#     zipcode       lat      long  sqft_living15  sqft_lot15     month  year  \
# 0  0.368687  0.761782  0.394979       0.400000    0.011601  0.545455   0.0
# 1  0.631313  0.683127  0.112971       0.318584    0.004985  0.545455   0.0
# 2  0.722222  0.707093  0.174059       0.226549    0.003837  0.545455   0.0
# 3  0.292929  0.515522  0.300418       0.212389    0.011556  0.272727   1.0
# 4  0.035354  0.690043  0.335565       0.361062    0.011188  0.727273   0.0
#
#         day
# 0  0.266667
# 1  0.566667
# 2  0.200000
# 3  0.900000
# 4  0.100000
#
# [5 rows x 21 columns]

# %%
def check_explode(norm):
    does_explode = True
    for i in range(1,len(norm)-1):
        if norm[i]<norm[i-1]:
            does_explode = False
    return does_explode

# %%
df_train.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.074225      0.223293      0.179645      0.008794      0.201480
# std        0.029476      0.105535      0.095728      0.024960      0.217059
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.062500      0.172414      0.111345      0.002704      0.000000
# 50%        0.062500      0.241379      0.162815      0.004269      0.200000
# 75%        0.093750      0.275862      0.228992      0.006166      0.400000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          waterfront          view     condition         grade    sqft_above  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.007000      0.057350      0.602275      0.408133      0.167621
# std        0.083377      0.188983      0.163398      0.131118      0.097864
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.500000      0.333333      0.096584
# 50%        0.000000      0.000000      0.500000      0.333333      0.140165
# 75%        0.000000      0.000000      0.750000      0.444444      0.219081
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ...           yr_built  yr_renovated       zipcode           lat  \
# count      ...       10000.000000  10000.000000  10000.000000  10000.000000
# mean       ...           0.618477      0.040311      0.390369      0.649693
# std        ...           0.256353      0.195722      0.270295      0.223018
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.443478      0.000000      0.161616      0.505549
# 50%        ...           0.660870      0.000000      0.323232      0.668168
# 75%        ...           0.843478      0.000000      0.587121      0.838829
# max        ...           1.000000      1.000000      1.000000      1.000000
#
#                long  sqft_living15    sqft_lot15         month          year  \
# count  10000.000000   10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.251643       0.271562      0.013884      0.508400      0.318500
# std        0.118330       0.122460      0.032441      0.282858      0.465918
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        0.155649       0.182301      0.005091      0.272727      0.000000
# 50%        0.237657       0.246018      0.007995      0.454545      0.000000
# 75%        0.325523       0.339823      0.010839      0.727273      1.000000
# max        1.000000       1.000000      1.000000      1.000000      1.000000
#
#                 day
# count  10000.000000
# mean       0.493403
# std        0.287392
# min        0.000000
# 25%        0.233333
# 50%        0.500000
# 75%        0.733333
# max        1.000000
#
# [8 rows x 21 columns]

# %%
all_info={}

# %%
import math
def calculate_weights_and_sse(df,max_iteration,check_iter_for_explode,lmbda,learning_rate=0.0000001):
    
    weight = np.array(np.random.randn(1,21)[0])
    
    number_of_iteration = 0
    sse_for_each_iter = [] 
    norm_for_this_lr = []
    while True:
        diff_in_y = df.dot(weight)-y_train
        
        
        gradient = (np.transpose(df)).dot(diff_in_y) + 2*lmbda*weight
        
        weight = weight - learning_rate*gradient 
        norm_for_gradient = math.sqrt(gradient.dot(gradient))
        
        sse = (np.transpose(diff_in_y)).dot(diff_in_y) + lmbda*(norm_for_gradient**2)
        
        
        
        
        
        #print('number of iteration',number_of_iteration,norm_for_gradient,'   sse =',sse)
        
        
        sse_for_each_iter.append(sse)
        
        norm_for_this_lr.append(norm_for_gradient)
        
        
        number_of_iteration = number_of_iteration + 1
        
        
        if(norm_for_gradient<=0.5):
            
            all_info[learning_rate] = {"whether converged":True,
                               "weights":weight,
                               "sse_for_each_iteration":sse_for_each_iter,
                               "number_of_iteration_used":number_of_iteration
                              }
            print("########################")
            print("number of itertion used for lmbda =",lmbda , " is ",number_of_iteration , 'and sse is ' ,sse)
            print("########################")
            break
            
            
        if(number_of_iteration == check_iter_for_explode and check_explode(norm_for_this_lr)):
            
            print('Gradient explodes for learning_rate =',learning_rate)
            all_info[learning_rate] = {"whether converged":False,
                               "weights":np.array(np.zeros(12)),
                               "sse_for_each_iteration":np.array([-1]*12),
                               "number_of_iteration_used":number_of_iteration
                              }
            break
            
        if(number_of_iteration==max_iteration):
    
            all_info[learning_rate] = {"whether converged":True,
                               "weights":weight,
                               "sse_for_each_iteration":sse_for_each_iter,
                               "number_of_iteration_used":number_of_iteration
                              }
            print("converges but takes too many iterations  for lambda =",lmbda)
            break
            
            
        if (number_of_iteration%5000)==0:
            print('number of iteration',number_of_iteration,norm_for_gradient,sse)
    
    print('checked for lambda = ',lmbda," now returning")
    return

# %%
lmbda_values = [0.001,0.01,0.1,0,1,10,100]
for lmb in lmbda_values[:1]:
    print('calculating everything for lmbda = ',lmb,'\n\n')
    calculate_weights_and_sse(df_train,200000,100,lmb)
# Out:
# calculating everything for lmbda =  0.001
#
#
# number of iteration 5000 3724.477496151205 85372.80842845482
# number of iteration 10000 2829.012221990169 68917.38976844912
# number of iteration 15000 2211.7472152985542 59504.5263933696
# number of iteration 20000 1757.5223575152509 53789.83744495832
# number of iteration 25000 1418.1890455089715 50206.99408327971
# number of iteration 30000 1163.0091724333947 47892.65317046962
# number of iteration 35000 970.2084165530088 46350.07567978826
# number of iteration 40000 823.8355898917913 45286.96361133074
# number of iteration 45000 712.0132725160366 44528.23644168771
# number of iteration 50000 625.8401358239721 43967.295520185464
# number of iteration 55000 558.655507318795 43538.168979996626
# number of iteration 60000 505.51144469468426 43199.31889833824
# number of iteration 65000 462.76882651458135 42924.09703348498
# number of iteration 70000 427.77687861036566 42695.0513873442
# number of iteration 75000 398.61811554733873 42500.49196315185
# number of iteration 80000 373.909279586502 42332.39646997407
# number of iteration 85000 352.6503811208532 42185.11855532382
# number of iteration 90000 334.1134615775111 42054.58116455685
# number of iteration 95000 317.7625969731019 41937.76590050847
# number of iteration 100000 303.1974157156267 41832.384771333185
# number of iteration 105000 290.1137052987159 41736.66553790837
# number of iteration 110000 278.27611700631576 41649.20867438096
# number of iteration 115000 267.49927818438664 41568.890092594214

# %%
lmbda_values = [0.001,0.01,0.1,0,1,10,100]
for lmb in lmbda_values[1:3]:
    print('calculating everything for lmbda = ',lmb,'\n\n')
    calculate_weights_and_sse(df_train,200000,100,lmb)
# Out:
# calculating everything for lmbda =  0.01
#
#
# number of iteration 5000 4495.514301456089 82070.4564975615
# number of iteration 10000 3333.202287551209 66948.13482234903
# number of iteration 15000 2545.7011625525433 58395.505617058676
# number of iteration 20000 1989.9228829712683 53296.08947977362
# number of iteration 25000 1587.6715884336604 50119.97849990004
# number of iteration 30000 1291.9868026397282 48060.663699775294
# number of iteration 35000 1072.4894229097952 46671.40896039073
# number of iteration 40000 908.3553147169056 45695.79414934507
# number of iteration 45000 784.7228770017585 44982.58849047686
# number of iteration 50000 690.7361989289451 44440.56667459411
# number of iteration 55000 618.3978848199724 44013.558322070094
# number of iteration 60000 561.8311207935488 43666.269555896055
# number of iteration 65000 516.7552217489294 43376.05026128728
# number of iteration 70000 480.0850042217369 43128.03092915451
# number of iteration 75000 449.61675076585703 42912.207648602955
# number of iteration 80000 423.7845473480391 42721.67136776009
# number of iteration 85000 401.4762183185069 42551.51817863509
# number of iteration 90000 381.8983343646276 42398.169687445086
# number of iteration 95000 364.4797248351639 42258.94305550864
# number of iteration 100000 348.80385134873995 42131.774721949
# number of iteration 105000 334.56203627318166 42015.039811759096
# number of iteration 110000 321.5213583693203 41907.43185872899
# number of iteration 115000 309.5026718514714 41807.88106616165
# number of iteration 120000 298.3655290371065 41715.497562526696
# number of iteration 125000 287.9977797589988 41629.53113769258
# number of iteration 130000 278.3083320888495 41549.34204197961
# number of iteration 135000 269.22205333198565 41474.37935432219
# number of iteration 140000 260.6761270445137 41404.164633081156
# number of iteration 145000 252.6174082755248 41338.27932881388
# number of iteration 150000 245.0004702880648 41276.35492994863
# number of iteration 155000 237.78613635143682 41218.0651322091
# number of iteration 160000 230.9403567764063 41163.1195338673
# number of iteration 165000 224.43333560844366 41111.258500611235
# number of iteration 170000 218.23884090687133 41062.24894049119
# number of iteration 175000 212.3336523412326 41015.880796519225
# number of iteration 180000 206.69711323051416 40971.96411191633
# number of iteration 185000 201.3107632998662 40930.32655709029
# number of iteration 190000 196.15803475152973 40890.81133235367
# number of iteration 195000 191.22399867298267 40853.275378907485
# converges but takes too many iterations  for lambda = 1e-07
# checked for learning rate =  1e-07  now returning
# calculating everything for lmbda =  0.1
#
#
# number of iteration 5000 4323.003109667794 84068.48420300419
# number of iteration 10000 3371.617109031002 69367.1536100443
# number of iteration 15000 2659.295963187149 60330.733884566034
# number of iteration 20000 2122.127910514865 54647.84329926783
# number of iteration 25000 1714.8679153196847 50986.34668449592
# number of iteration 30000 1404.806629821915 48564.61039522115
# number of iteration 35000 1167.8905883989257 46916.67311397116
# number of iteration 40000 986.179895051944 45760.646117585304
# number of iteration 45000 846.1530810061802 44923.55718128876
# number of iteration 50000 737.5581388967312 44297.73435866584
# number of iteration 55000 652.6148279318627 43815.140804919756
# number of iteration 60000 585.4400489592124 43432.08733214168
# number of iteration 65000 531.6148959872836 43120.02498504383
# number of iteration 70000 487.84584950306845 42859.94108288877
# number of iteration 75000 451.69484777561786 42638.91294993866
# number of iteration 80000 421.3649642403963 42447.96588588973
# number of iteration 85000 395.53318080225165 42280.72668245765
# number of iteration 90000 373.2228750993794 42132.56683106323
# number of iteration 95000 353.70875815529945 42000.05002042369
# number of iteration 100000 336.4473314177381 41880.57064036759
# number of iteration 105000 321.02671949766085 41772.11350980347
# number of iteration 110000 307.1308000281603 41673.09147475526
# number of iteration 115000 294.5136597686151 41582.2336921293
# number of iteration 120000 282.981399154318 41498.5073810679
# number of iteration 125000 272.37911885367123 41421.06201460408
# number of iteration 130000 262.58154534243926 41349.18880283502
# number of iteration 135000 253.4862119900148 41282.290771476924
# number of iteration 140000 245.00844124445416 41219.86030669109
# number of iteration 145000 237.07760466940792 41161.46204965737
# number of iteration 150000 229.63429791862947 41106.719686799035
# number of iteration 155000 222.6281781050786 41055.305620705614
# number of iteration 160000 216.01628674486204 41006.93280204509
# number of iteration 165000 209.7617334130071 40961.34820418054
# number of iteration 170000 203.83265100733172 40918.32756170065
# number of iteration 175000 198.20135826772335 40877.67109213835
# number of iteration 180000 192.84368246622813 40839.19999011902
# number of iteration 185000 187.73840734989201 40802.753533817675
# number of iteration 190000 182.86682008881348 40768.18668075286
# number of iteration 195000 178.2123372387352 40735.36805754651
# converges but takes too many iterations  for lambda = 1e-07
# checked for learning rate =  1e-07  now returning

# %%
lmbda_values = [0.001,0.01,0.1,1,10,100]
for lmb in lmbda_values[3:5]:
    print('calculating everything for lmbda = ',lmb,'\n\n')
    calculate_weights_and_sse(df_train,200000,100,lmb)
# Out:
# calculating everything for lmbda =  1
#
#
# number of iteration 5000 4121.833607788472 81627.40432199505
# number of iteration 10000 3231.592200076728 68179.3398445923
# number of iteration 15000 2564.394254872993 59808.43361125054
# number of iteration 20000 2060.9867700868517 54465.63626913649
# number of iteration 25000 1679.0063104316453 50963.730822811005
# number of iteration 30000 1387.6452846626767 48602.6245736592
# number of iteration 35000 1164.1794452118324 46962.66975548339
# number of iteration 40000 991.6680145709943 45788.31847484261
# number of iteration 45000 857.4025781073323 44921.465218642894
# number of iteration 50000 751.834679239708 44262.66511862581
# number of iteration 55000 667.8083778931332 43748.26060426088
# number of iteration 60000 599.9890737391116 43336.72227543032
# number of iteration 65000 544.4244515596959 43000.396354546596
# number of iteration 70000 498.20163304187554 42720.461437760736
# number of iteration 75000 459.17993953664813 42483.81057588551
# number of iteration 80000 425.78545965276896 42281.10009702138
# number of iteration 85000 396.8561256340714 42105.512527053215
# number of iteration 90000 371.52712854752474 41951.96102952602
# number of iteration 95000 349.1475856791614 41816.56976810063
# number of iteration 100000 329.22072214892864 41696.32870209051
# number of iteration 105000 311.3613136864542 41588.86005100936
# number of iteration 110000 295.2655591496038 41492.25724049569
# number of iteration 115000 280.6897786982612 41404.97160879985
# number of iteration 120000 267.43531894620037 41325.73110263514
# number of iteration 125000 255.33779842448521 41253.48077576293
# number of iteration 130000 244.2593805114139 41187.33842112321
# number of iteration 135000 234.08315880654533 41126.56090545392
# number of iteration 140000 224.70902078335445 41070.518215438125
# number of iteration 145000 216.05055150160183 41018.67316241937
# number of iteration 150000 208.0326747958141 40970.56531188228
# number of iteration 155000 200.5898227789068 40925.7981184992
# number of iteration 160000 193.66448866558494 40884.02852945998
# number of iteration 165000 187.2060619366206 40844.95851359065
# number of iteration 170000 181.1698750604313 40808.32811059887
# number of iteration 175000 175.51641172472446 40773.90969251565
# number of iteration 180000 170.21064080194466 40741.50320036676
# number of iteration 185000 165.22145012594353 40710.932171458604
# number of iteration 190000 160.5211609927671 40682.04041187427
# number of iteration 195000 156.0851090710167 40654.68919855416
# converges but takes too many iterations  for lambda = 1
# checked for learning rate =  1e-07  now returning
# calculating everything for lmbda =  10
#
#
# number of iteration 5000 4827.138074700647 92113.96764436706
# number of iteration 10000 3612.7621208637725 74404.39929544539
# number of iteration 15000 2786.0011757593948 64012.61867540893
# number of iteration 20000 2183.6823651520144 57631.67568345554
# number of iteration 25000 1738.9290569694683 53576.938587629586
# number of iteration 30000 1408.828769302963 50908.376938016474
# number of iteration 35000 1162.9679638733505 49085.783823198704
# number of iteration 40000 979.1514283784537 47792.31575117664
# number of iteration 45000 840.9332211257627 46838.61041321191
# number of iteration 50000 736.0519070171296 46109.350290605405
# number of iteration 55000 655.3931853299648 45532.92091985135
# number of iteration 60000 592.2529529241335 45063.90453529266
# number of iteration 65000 541.7709840734431 44672.83305770725
# number of iteration 70000 500.4748306414634 44340.10911919476
# number of iteration 75000 465.9120822660848 44052.35224368755
# number of iteration 80000 436.3622258983662 43800.1732529133
# number of iteration 85000 410.6193661945249 43576.79945084082
# number of iteration 90000 387.83420420482577 43377.212360337406
# number of iteration 95000 367.4024305442128 43197.59785714518
# number of iteration 100000 348.88757321310345 43034.98907880743
# number of iteration 105000 331.96841751115875 42887.02990450169
# number of iteration 110000 316.4034602033106 42751.81497043678
# number of iteration 115000 302.00694888426943 42627.779064605886
# number of iteration 120000 288.6327064746146 42513.61894879602
# number of iteration 125000 276.1631531138849 42408.23688253571
# number of iteration 130000 264.5017901327099 42310.69896215429
# number of iteration 135000 253.56799318857796 42220.2037809519
# number of iteration 140000 243.2933522805309 42136.05842667262
# number of iteration 145000 233.61905533401043 42057.65979869003
# number of iteration 150000 224.493982573302 41984.47985477924
# number of iteration 155000 215.8732908145789 41916.05381140708
# number of iteration 160000 207.71734021903714 41851.97059938068
# number of iteration 165000 199.99086427050977 41791.865066511244
# number of iteration 170000 192.66231553459357 41735.411550924706
# number of iteration 175000 185.703340824567 41682.318542028974
# number of iteration 180000 179.08835345585996 41632.324213346335
# number of iteration 185000 172.7941797275246 41585.192660566805
# number of iteration 190000 166.79976319414774 41540.71071465961
# number of iteration 195000 161.08591470646112 41498.685227341266
# converges but takes too many iterations  for lambda = 10
# checked for learning rate =  1e-07  now returning

# %%
calculate_weights_and_sse(df_train,200000,100,100)
# Out:
# number of iteration 5000 3908.6105226461273 83607.79427662218
# number of iteration 10000 2792.9261808924584 71574.84755542598
# number of iteration 15000 2061.624910212448 64546.79008602121
# number of iteration 20000 1565.4680988111406 60171.041095889545
# number of iteration 25000 1219.5492483069465 57304.677813536764
# number of iteration 30000 972.0718098878931 55348.38697007869
# number of iteration 35000 790.2724731706306 53968.11511158037
# number of iteration 40000 653.0727779679752 52967.665484747005
# number of iteration 45000 546.8003956738465 52226.39114895445
# number of iteration 50000 462.52004492262745 51667.06071627957
# number of iteration 55000 394.32243801760285 51238.49643387992
# number of iteration 60000 338.2271780668441 50905.77988526675
# number of iteration 65000 291.4866501258578 50644.49672328035
# number of iteration 70000 252.1489342576755 50437.22364108219
# number of iteration 75000 218.78476902700984 50271.30878564546
# number of iteration 80000 190.31661763602256 50137.42629748969
# number of iteration 85000 165.91057829523604 50028.610316754726
# number of iteration 90000 144.90683085774478 49939.59522013665
# number of iteration 95000 126.77380032482033 49866.35672761466
# number of iteration 100000 111.07707447051882 49805.78777360782
# number of iteration 105000 97.45766106193845 49755.46651147777
# number of iteration 110000 85.61629654814924 49713.48830476563
# number of iteration 115000 75.30178669639776 49678.34275226248
# number of iteration 120000 66.30211733206399 49648.822774589
# number of iteration 125000 58.43752873944803 49623.956761855145
# number of iteration 130000 51.55502417209871 49602.95746555336
# number of iteration 135000 45.52395412248995 49585.183156866864
# number of iteration 140000 40.23242618916467 49570.10784873249
# number of iteration 145000 35.584360566647106 49557.2982720219
# number of iteration 150000 31.497058077019915 49546.395927028076
# number of iteration 155000 27.899179974194187 49537.10298053587
# number of iteration 160000 24.729061699674023 49529.17110078155
# number of iteration 165000 21.933299527810657 49522.392555134924
# number of iteration 170000 19.465561580232695 49516.59306439427
# number of iteration 175000 17.285584268609036 49511.62603133516
# number of iteration 180000 15.35832266394379 49507.36785238787
# number of iteration 185000 13.653229143983136 49503.714089041794
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-f88192712a65> in <module>()
# ----> 1 calculate_weights_and_sse(df_train,200000,100,100)
#
# <ipython-input-121-b95b23c615da> in calculate_weights_and_sse(df, max_iteration, check_iter_for_explode, lmbda, learning_rate)
#      15         weight = weight - learning_rate*gradient
#      16
# ---> 17         sse = (np.transpose(diff_in_y)).dot(diff_in_y)
#      18
#      19
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in dot(self, other)
#    2045                                      index=other.columns).__finalize__(self)
#    2046         elif isinstance(other, Series):
# -> 2047             return np.dot(lvals, rvals)
#    2048         elif isinstance(rvals, np.ndarray):
#    2049             return np.dot(lvals, rvals)
#
# KeyboardInterrupt:

# %%
###Training SSE
for l in lmbda_values:
    data_l = all_info[l]
    sse_value_train=data_l['sse_for_each_iteration']
    length = len(sse_value_train)
    print("lambda = ",l," and sse = ",sse_value_train[length-1] ," for 200000 iterations")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-233883fc6fff> in <module>()
#       1 ###Training SSE
#       2 for l in lmbda_values:
# ----> 3     data_l = all_info[l]
#       4     sse_value_train=data_l['sse_for_each_iteration']
#       5     length = len(sse_value_train)
#
# KeyError: 0.001
